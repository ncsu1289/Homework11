# %% [markdown]
# Step 3 - Climate Analysis and Exploration
#     You are now ready to use Python and SQLAlchemy to do basic climate analysis and data exploration on your new weather station tables. All of the following analysis should be completed using SQLAlchemy ORM queries, Pandas, and Matplotlib.
#     Create a Jupyter Notebook file called climate_analysis.ipynb and use it to complete your climate analysis and data exporation.
#     Choose a start date and end date for your trip. Make sure that your vacation range is approximately 3-15 days total.
# Use SQLAlchemy create_engine to connect to your sqlite database.
# Use SQLAlchemy automap_base() to reflect your tables into classes and save a reference to those classes called Station and Measurement.
# Precipitation Analysis
#
# Design a query to retrieve the last 12 months of precipitation data.
# Select only the date and prcp values.
# Load the query results into a Pandas DataFrame and set the index to the date column.
# Plot the results using the DataFrame plot method.

# %%
import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import numpy as np

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine, inspect, func
from sqlalchemy.orm import Session

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
Base=automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
inspector=inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
columns=inspector.get_columns('measurement')
for column in columns:
    print(column["name"],column["type"])
# Out:
# id INTEGER
# station VARCHAR(255)
# date INTEGER
# prcp FLOAT
# tobs INTEGER

# %%
Measurement=Base.classes.measurement

# %%
Station=Base.classes.station

# %%
session=Session(engine)

# %%
first_row=session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x11a6e45f8>,
#  'date': '2010-01-01 00:00:00.000000',
#  'id': 0,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'tobs': 65}

# %%
dates_prcp=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>'20161209').order_by(Measurement.date.desc())

# %% [markdown]
# dp=pd.DataFrame(dates_prcp,columns=['date','prcp'])
# dp.set_index('date', inplace=True)
# dp.head()

# %% [markdown]
# dp.set_index(date,inplace='True')

# %% [markdown]
# date=[dates_prcp[0] for d in dates_prcp]

# %% [markdown]
# prcp=[date_prcp[1] for p in date_prcp]

# %%
date_prcp=engine.execute('SELECT date,prcp FROM Measurement GROUP BY date ORDER BY date desc limit 350').fetchall()

# %% [markdown]
# dates=[date_prcp[0] for d in date_prcp]

# %% [markdown]
# prcp1=[date_prcp[1] for p in date_prcp]

# %%
dp=pd.DataFrame(date_prcp,columns=['date','prcp'])

# %%
dp['date']=pd.to_datetime(dp['date']).dt.date

# %%
dp.set_index('date', inplace=True)
dp.head()
# Out:
#             prcp
# date
# 2017-08-23  0.45
# 2017-08-22  0.50
# 2017-08-21  0.56
# 2017-08-20  0.00
# 2017-08-19  0.09

# %%
dp.iloc[::-1].plot.bar(title="Last Year's Precipitation")
plt.tight_layout()
plt.savefig("Last Year's Precipitation")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Station Analysis
#
#     Design a query to calculate the total number of stations.
#     Design a query to find the most active stations.
#     List the stations and observation counts in descending order
#     Which station has the highest number of observations?
#     Design a query to retrieve the last 12 months of temperature observation data (tobs).
# Filter by the station with the highest number of observations.
# Plot the results as a histogram with bins=12.first_row=session.query(Measurement).first()

# %% [markdown]
#     Design a query to calculate the total number of stations.

# %%
station_count=session.query(Station).count()

# %%
print(station_count)
# Out:
# 9

# %% [markdown]
#     Design a query to find the most active stations.

# %%
asc=engine.execute('SELECT station,prcp FROM Measurement').fetchall()

# %%
active_station=pd.DataFrame(asc,columns=['station','prcp'])

# %%
active_station.dtypes
# Out:
# station     object
# prcp       float64
# dtype: object

# %%
grouped_active_station=active_station.groupby(['station'])

# %%
grouped_active_station.sum().sort_values(['prcp'],ascending=False).head()
# Out:
#                 prcp
# station
# USC00516128  1068.09
# USC00519281   588.64
# USC00513117   382.62
# USC00519523   295.68
# USC00514830   234.49

# %% [markdown]
#     List the stations and observation counts in descending order
#     Which station has the highest number of observations?

# %%
tobc=engine.execute('SELECT station,tobs FROM Measurement').fetchall()

# %%
observation_count=pd.DataFrame(tobc,columns=['station','tobs'])

# %%
observation_count.dtypes
# Out:
# station    object
# tobs        int64
# dtype: object

# %%
observation_count['station']=observation_count['station'].astype('|S')

# %%
observation_count.dtypes
# Out:
# station     |S32
# tobs       int64
# dtype: object

# %% [markdown]
# observation_count['station']=observation_count['station'].str.split('')

# %% [markdown]
# observation_count.dtypes

# %%
observation_count.head()
# Out:
#   station  tobs
# 0  b'nan'    65
# 1  b'nan'    63
# 2  b'nan'    74
# 3  b'nan'    76
# 4  b'nan'    73

# %%
grouped_observation=observation_count.groupby(['station'])

# %%
plt.figure();
grouped_observation.plot(kind='hist', bins=12)
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# ...

# %%
grouped_observation.count().sort_values(['tobs'],ascending=False).head(15)
# Out:
#              tobs
# station
# USC00519281  2772
# USC00519397  2724
# USC00513117  2709
# USC00519523  2669
# USC00516128  2612
# USC00514830  2202
# USC00511918  1979
# USC00517948  1372
# USC00518838   511

# %%
x_axis=int(station_count)
observations=[0,250,500,750,1000,1250,1500,1750,2000,2250,2500,2750,3000]
grouped_observation.plot.hist(by='station', bins=12)
plt.bar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# grouped_observation.hist(grouped_observation,column='station',bins=12)

# %% [markdown]
#     Design a query to retrieve the last 12 months of temperature observation data (tobs).

# %%
tob_twelve=session.query(Measurement.date,Measurement.tobs).filter(Measurement.date>'20161209').order_by(Measurement.date.desc()).all()

# %%
date=[]
tobs=[]

for tt in tob_twelve:
    date.append(tt[0])
    tobs.append(tt[1])

# %%
twelve_sum=list(zip(date,tobs))

# %%
t_sum=pd.DataFrame(twelve_sum)
t_sum.head()
# Out:
#                             0   1
# 0  2017-08-23 00:00:00.000000  81
# 1  2017-08-23 00:00:00.000000  82
# 2  2017-08-23 00:00:00.000000  82
# 3  2017-08-23 00:00:00.000000  76
# 4  2017-08-22 00:00:00.000000  82

# %%
rename_t_sum=t_sum.rename(columns={"0":"date","1":"temperature_observances"})

# %%
rename_t_sum.head()
# Out:
#                             0   1
# 0  2017-08-23 00:00:00.000000  81
# 1  2017-08-23 00:00:00.000000  82
# 2  2017-08-23 00:00:00.000000  82
# 3  2017-08-23 00:00:00.000000  76
# 4  2017-08-22 00:00:00.000000  82

# %%
tob_twelve=engine.execute('SELECT station,date,tobs FROM Measurement').fetchall()

# %%
twelve_months=pd.DataFrame(tob_twelve,columns=['station','date','tobs'])

# %%
twelve_months['date']=pd.to_datetime(twelve_months['date']).dt.date

# %%
twelve_months.head()
# Out:
#        station        date  tobs
# 0  USC00519397  2010-01-01    65
# 1  USC00519397  2010-01-02    63
# 2  USC00519397  2010-01-03    74
# 3  USC00519397  2010-01-04    76
# 4  USC00519397  2010-01-06    73

# %%
t_m=twelve_months.sort_values(['date'],ascending=False)

# %%
group_twelve=t_m.groupby(['date'])

# %%
group_twelve.head()
# Out:
#            station        date  tobs
# 19549  USC00516128  2017-08-23    76
# 12186  USC00519523  2017-08-23    82
# 2723   USC00519397  2017-08-23    81
# 7634   USC00514830  2017-08-23    82
# 12185  USC00519523  2017-08-22    82
# 2722   USC00519397  2017-08-22    82
# 19548  USC00516128  2017-08-22    76
# 7633   USC00514830  2017-08-21    79
# 19547  USC00516128  2017-08-21    76
# 12184  USC00519523  2017-08-21    82
# 2721   USC00519397  2017-08-21    81
# 19546  USC00516128  2017-08-20    78
# 2720   USC00519397  2017-08-20    81
# 7632   USC00514830  2017-08-20    80
# 19545  USC00516128  2017-08-19    71
# 7631   USC00514830  2017-08-19    80
# 12183  USC00519523  2017-08-19    85
# 2719   USC00519397  2017-08-19    79
# 7630   USC00514830  2017-08-18    77
# 14958  USC00519281  2017-08-18    79
# 2718   USC00519397  2017-08-18    80
# 19544  USC00516128  2017-08-18    76
# 7629   USC00514830  2017-08-17    78
# 12182  USC00519523  2017-08-17    83
# ...

# %% [markdown]
# Temperature Analysis
#
#     Write a function called calc_temps that will accept a start date and end date in the format %Y-%m-%d and return the minimum, average, and maximum temperatures for that range of dates.
#     Use the calc_temps function to calculate the min, avg, and max temperatures for your trip using the matching dates from the previous year (i.e. use "2017-01-01" if your trip start date was "2018-01-01")
# Plot the min, avg, and max temperature from your previous query as a bar chart.
# Use the average temperature as the bar height.
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr).

# %%
def calc_temps():
    years=raw_input("Please enter the year starting your trip")
    months=raw_input("Please enter the starting month for your trip")
    days=raw_input("Please enter the starting day of your trip")
    start_date=int(years)+'-'+int(months)+'-'+int(days)
    year_e=raw_input("Please enter the year ending your trip")
    month_e=raw_input("Please enter the ending month for your trip")
    day_e=raw_input("Please enter the ending day of your trip")
    end_date=int(year_e)+'-'+int(month_e)+'-'+int(day_e)
    Measurement=Base.classes.measurement
    Station=Base.classes.station
    session=Session(engine)
    min_temp=engine.execute('SELECT MIN(tobs) FROM Measurement WHERE date BETWEEN int(start_date) AND int(end_date)').fetchall()
    max_temp=engine.execute('SELECT MAX(tobs) FROM Measurement WHERE date BETWEEN int(start_date) AND int(end_date)').fetchall()
    avg_temp=engine.execute('SELECT AVG(tobs) FROM Measurement WHERE date Between int(start_date) AND int(end_date)').fetchall()
    print("The minimum, maximum and average temperatures for last year and during the time for your trip are %s,%s,%s") % (min_temp, max_temp, avg_temp)

# %%
min_temp=engine.execute('SELECT MIN('tobs') FROM measurement WHERE date BETWEEN '2017-03-15' AND '2017-03-20'')
# Out:
#   File "<ipython-input-114-1b77c94f6e9b>", line 1
#     min_temp=engine.execute('SELECT MIN('tobs') FROM measurement WHERE date BETWEEN '2017-03-15' AND '2017-03-20'')
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Step 4 - Climate App
# Now that you have completed your initial analysis, design a Flask api based on the queries that you have just developed.
# Use FLASK to create your routes.
# Routes
#
# /api/v1.0/precipitation
#     Query for the dates and temperature observations from the last year.
#     Convert the query results to a Dictionary using date as the key and tobs as the value.
# Return the json representation of your dictionary.
# /api/v1.0/stations
#     Return a json list of stations from the dataset.
# /api/v1.0/tobs
#     Return a json list of Temperature Observations (tobs) for the previous year
# /api/v1.0/<start> and /api/v1.0/<start>/<end>
#     Return a json list of the minimum temperature, the average temperature, and the max temperature for a given start or start-end range.
# When given the start only, calculate TMIN, TAVG, and TMAX for all dates greater than and equal to the start date.
# When given the start and the end date, calculate the TMIN, TAVG, and TMAX for dates between the start and end date inclusive.

# %%
from flask import Flask

# %%
app=Flask(__name__)

# %%
@app.route("/")
def home():
    print("Server received request for the Home page.")
    return "Welcome to the initial page."

# %%
@app.route("/calc_temps")
def calc_temps():
    years=raw_input("Please enter the year starting your trip")
    months=raw_input("Please enter the starting month for your trip")
    days=raw_input("Please enter the starting day of your trip")
    start_date=int(years)+'-'+int(months)+'-'+int(days)
    year_e=raw_input("Please enter the year ending your trip")
    month_e=raw_input("Please enter the ending month for your trip")
    day_e=raw_input("Please enter the ending day of your trip")
    end_date=int(year_e)+'-'+int(month_e)+'-'+int(day_e)
    Measurement=Base.classes.measurement
    Station=Base.classes.station
    session=Session(engine)
    min_temp=engine.execute('SELECT MIN(tobs) FROM Measurement WHERE date BETWEEN int(start_date) AND int(end_date)').fetchall()
    max_temp=engine.execute('SELECT MAX(tobs) FROM Measurement WHERE date BETWEEN int(start_date) AND int(end_date)').fetchall()
    avg_temp=engine.execute('SELECT AVG(tobs) FROM Measurement WHERE date Between int(start_date) AND int(end_date)').fetchall()
    print("The minimum, maximum and average temperatures for last year and during the time for your trip are %s,%s,%s") % (min_temp, max_temp, avg_temp)

# %%
if __name__== "__main__":
    app.run(debug=True)
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
